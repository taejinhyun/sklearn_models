# %% [markdown]
# **Objective of the notebook:**
#
# 주택 구매를 하기 위해 부동산을 알아볼 때, 해당 건물에 대한 다양한 정보들이 주택의 매매가에 영향을 미침을 알 수 있다.
# 이번에는 주택에 대한 79개의 Feature들을 통하여 Iowa주의 Ames에 있는 주택의 가격을 예측하고자 한다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **About the dataset:**
#
# House Prices: Advanced Regression Techniques
#
# 출처 : Kaggle (https://www.kaggle.com/c/house-prices-advanced-regression-techniques)
#
# Kaggle에서는 다음과 같은 데이터를 제공한다.
# * train.csv
# * test.csv
#
# 데이터셋의 각 행은 하나의 주택의 정보와 가격이다.
#
# 데이터 필드는 다음과 같다.

# %%
variable = pd.read_excel('variable.xlsx')
variable
# Out:
#          Variable        Scale  \
# 0              Id  Categorical
# 1      MSSubClass  Categorical
# 2        MSZoning  Categorical
# 3     LotFrontage   Continuous
# 4         LotArea   Continuous
# 5          Street  Categorical
# 6           Alley  Categorical
# 7        LotShape  Categorical
# 8     LandContour  Categorical
# 9       Utilities  Categorical
# 10      LotConfig  Categorical
# 11      LandSlope  Categorical
# 12   Neighborhood  Categorical
# 13     Condition1  Categorical
# 14     Condition2  Categorical
# 15       BldgType  Categorical
# 16     HouseStyle  Categorical
# 17    OverallQual      Ordinal
# 18    OverallCond      Ordinal
# 19      YearBuilt   Continuous
# 20   YearRemodAdd   Continuous
# 21      RoofStyle  Categorical
# 22       RoofMatl  Categorical
# 23    Exterior1st  Categorical
# 24    Exterior2nd  Categorical
# 25     MasVnrType  Categorical
# 26     MasVnrArea   Continuous
# 27      ExterQual      Ordinal
# 28      ExterCond      Ordinal
# ...

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
print('Train Data Shape : {}'.format(train_df.shape))
print('Test Data Shape : {}'.format(test_df.shape))
# Out:
# Train Data Shape : (1460, 81)
# Test Data Shape : (1459, 80)

# %% [markdown]
# Train 데이터에는 1460개의 데이터와 81개의 변수가 존재한다.
# Test 데이터는 Kaggle competition에서 데이터를 가져왔기 떄문에 SalePrice가 존재하지 않는다.

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %% [markdown]
# **result from the seminar:**
#
# 위 데이터는 Feature에 해당하는 변수가 79개이다. 분석을 하기 위해서는 feature engineering을 통하여 Feature의 갯수를 줄일 필요가 있다. feature engineering에는 많은 시간이 소요될 것이라 예상되기에(아직 feature engineering에 대한 지식이 부족함으로 판단) 우선적으로 전처리에 시간에 크게 소요되지 않는 데이터를 분석 후 House Prices 데이터를 살펴보기로 하였다.
